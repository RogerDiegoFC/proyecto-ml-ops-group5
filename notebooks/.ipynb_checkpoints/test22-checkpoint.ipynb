# %%
# !pip --version
# Out:
# pip 25.1 from /home/speranza/miniconda3/lib/python3.13/site-packages/pip (python 3.13)

# %%
# !pip install numpy
# !pip install mlflow torch
# Out:
# Collecting numpy
#   Downloading numpy-2.3.2-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Downloading numpy-2.3.2-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 7.3 MB/s eta 0:00:000m eta 0:00:010:01:01
# Installing collected packages: numpy
# Successfully installed numpy-2.3.2
# Collecting mlflow
#   Downloading mlflow-3.3.2-py3-none-any.whl.metadata (30 kB)
# Collecting torch
#   Downloading torch-2.8.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting mlflow-skinny==3.3.2 (from mlflow)
#   Downloading mlflow_skinny-3.3.2-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.3.2 (from mlflow)
#   Downloading mlflow_tracing-3.3.2-py3-none-any.whl.metadata (19 kB)
# Collecting Flask<4 (from mlflow)
#   Using cached flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.16.5-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: cryptography<46,>=43.0.0 in /home/speranza/miniconda3/lib/python3.13/site-packages (from mlflow) (45.0.5)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting matplotlib<4 (from mlflow)
#   Downloading matplotlib-3.10.6-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<3 in /home/speranza/miniconda3/lib/python3.13/site-packages (from mlflow) (2.3.2)
# Collecting pandas<3 (from mlflow)
#   Downloading pandas-2.3.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Collecting pyarrow<22,>=4.0.0 (from mlflow)
#   Downloading pyarrow-21.0.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting scikit-learn<2 (from mlflow)
#   Downloading scikit_learn-1.7.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting scipy<2 (from mlflow)
#   Downloading scipy-1.16.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Downloading sqlalchemy-2.0.43-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.3.2->mlflow)
#   Downloading cachetools-6.2.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: click<9,>=7.0 in /home/speranza/miniconda3/lib/python3.13/site-packages (from mlflow-skinny==3.3.2->mlflow) (8.2.1)
# Collecting cloudpickle<4 (from mlflow-skinny==3.3.2->mlflow)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.3.2->mlflow)
#   Downloading databricks_sdk-0.64.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.3.2->mlflow)
#   Downloading fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.3.2->mlflow)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /home/speranza/miniconda3/lib/python3.13/site-packages (from mlflow-skinny==3.3.2->mlflow) (8.7.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.3.2->mlflow)
#   Downloading opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.3.2->mlflow)
#   Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /home/speranza/miniconda3/lib/python3.13/site-packages (from mlflow-skinny==3.3.2->mlflow) (25.0)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.3.2->mlflow)
#   Using cached protobuf-6.32.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /home/speranza/miniconda3/lib/python3.13/site-packages (from mlflow-skinny==3.3.2->mlflow) (2.11.7)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/speranza/miniconda3/lib/python3.13/site-packages (from mlflow-skinny==3.3.2->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/speranza/miniconda3/lib/python3.13/site-packages (from mlflow-skinny==3.3.2->mlflow) (2.32.4)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.3.2->mlflow)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /home/speranza/miniconda3/lib/python3.13/site-packages (from mlflow-skinny==3.3.2->mlflow) (4.12.2)
# Collecting uvicorn<1 (from mlflow-skinny==3.3.2->mlflow)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: cffi>=1.14 in /home/speranza/miniconda3/lib/python3.13/site-packages (from cryptography<46,>=43.0.0->mlflow) (1.17.1)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /home/speranza/miniconda3/lib/python3.13/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Collecting starlette<0.48.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.3.2->mlflow)
#   Downloading starlette-0.47.3-py3-none-any.whl.metadata (6.2 kB)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /home/speranza/miniconda3/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/speranza/miniconda3/lib/python3.13/site-packages (from Flask<4->mlflow) (3.0.2)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.3.2->mlflow)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/speranza/miniconda3/lib/python3.13/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /home/speranza/miniconda3/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.3.2->mlflow) (3.23.0)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow)
#   Downloading contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4->mlflow)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow)
#   Downloading fonttools-4.59.2-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (109 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4->mlflow)
#   Downloading kiwisolver-1.4.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib<4->mlflow)
#   Downloading pillow-11.3.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib<4->mlflow)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting opentelemetry-semantic-conventions==0.57b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.3.2->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/speranza/miniconda3/lib/python3.13/site-packages (from pandas<3->mlflow) (2025.2)
# Collecting tzdata>=2022.7 (from pandas<3->mlflow)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/speranza/miniconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/speranza/miniconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/speranza/miniconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (0.4.0)
# Requirement already satisfied: six>=1.5 in /home/speranza/miniconda3/lib/python3.13/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/speranza/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/speranza/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/speranza/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow) (2025.8.3)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting joblib>=1.2.0 (from scikit-learn<2->mlflow)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2->mlflow)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow)
#   Downloading greenlet-3.2.4-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/speranza/miniconda3/lib/python3.13/site-packages (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in /home/speranza/miniconda3/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3
cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.3 MB/s eta 0:00:00
# Downloading pillow-11.3.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 10.8 MB/s eta 0:00:000:00:010:00:01
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 4.0 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 1.6 MB/s eta 0:00:000:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 5.3 MB/s eta 0:00:007 MB/s eta 0:00:01
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, werkzeug, uvicorn, tzdata, triton, threadpoolctl, sympy, sqlparse, smmap, scipy, pyparsing, pyasn1, pyarrow, protobuf, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, Mako, kiwisolver, joblib, itsdangerous, gunicorn, greenlet, graphql-core, fsspec, fonttools, filelock, cycler, contourpy, cloudpickle, cachetools, blinker, starlette, sqlalchemy, scikit-learn, rsa, pyasn1-modules, pandas, opentelemetry-api, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, matplotlib, graphql-relay, gitdb, Flask, docker, opentelemetry-semantic-conventions, nvidia-cusolver-cu12, graphene, google-auth, gitpython, fastapi, alembic, torch, opentelemetry-sdk, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69/69 [mlflow]69 [mlflow]67/69 [mlflow-skinny]]c-conventions]
# Successfully installed Flask-3.1.2 Mako-1.3.10 alembic-1.16.5 blinker-1.9.0 cachetools-5.5.2 cloudpickle-3.1.1 contourpy-1.3.3 cycler-0.12.1 databricks-sdk-0.64.0 docker-7.1.0 fastapi-0.116.1 filelock-3.19.1 fonttools-4.59.2 fsspec-2025.7.0 gitdb-4.0.12 gitpython-3.1.45 google-auth-2.40.3 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 greenlet-3.2.4 gunicorn-23.0.0 itsdangerous-2.2.0 joblib-1.5.2 kiwisolver-1.4.9 matplotlib-3.10.6 mlflow-3.3.2 mlflow-skinny-3.3.2 mlflow-tracing-3.3.2 mpmath-1.3.0 networkx-3.5 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 opentelemetry-api-1.36.0 opentelemetry-sdk-1.36.0 opentelemetry-semantic-conventions-0.57b0 pandas-2.3.2 pillow-11.3.0 protobuf-6.32.0 pyarrow-21.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pyparsing-3.2.3 rsa-4.9.1 scikit-learn-1.7.1 scipy-1.16.1 smmap-5.0.2 sqlalchemy-2.0.43 sqlparse-0.5.3 starlette-0.47.3 sympy-1.14.0 threadpoolctl-3.6.0 torch-2.8.0 triton-3.4.0 tzdata-2025.2 uvicorn-0.35.0 werkzeug-3.1.3

# %%
import sys
print(sys.version)
# Out:
# 3.9.23 (main, Jun  5 2025, 13:40:20)
# [GCC 11.2.0]

# %%
import mlflow
import mlflow.pytorch
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import time
import random

# --------------------------
# Configuración del experimento
# --------------------------
mlflow.set_tracking_uri("file:/home/speranza/Documentos/OPL-proyecto-final/mlruns")
mlflow.set_experiment("modelo_proy_final_5")
# Modelo ficticio de tensores
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(10, 5)
        self.fc2 = nn.Linear(5, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Datos simulados
X = torch.randn(100, 10)
y = torch.randn(100, 1)

# --------------------------
# Emulación de entrenamiento
# --------------------------
import random

with mlflow.start_run(run_name="entrenamiento_run") as run:
    model = SimpleNet()
    criterion = nn.MSELoss()
    optimizer = optim.SGD(model.parameters(), lr=0.01)

    epochs = 20
    max_progress = 0.4  # Máximo 40%
    base_progress = np.linspace(0.05, max_progress, epochs)  # progreso base

    for epoch in range(epochs):
        # Forward pass ficticio
        outputs = model(X)
        loss = criterion(outputs, y)

        # Backward pass ficticio
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Métrica simulada de "accuracy" con más variabilidad
        noise = random.uniform(-0.02, 0.05)  # fluctuación mayor
        simulated_accuracy = max(0.0, min(base_progress[epoch] + noise, max_progress))

        # Log en MLflow con fluctuación en loss también
        loss_noise = loss.item() * random.uniform(0.95, 1.05)
        mlflow.log_metric("loss", loss_noise, step=epoch)
        mlflow.log_metric("accuracy", simulated_accuracy, step=epoch)

        print(f"Epoch {epoch+1}/{epochs} - Loss: {loss_noise:.4f} - Accuracy: {simulated_accuracy:.3f}")
        time.sleep(5.5)  # simula tiempo de entrenamiento


    # Guardar modelo final (opcional)
    mlflow.pytorch.log_model(model, "simple_net_model")

print("Simulación finalizada. Revisa MLflow UI para ver métricas y modelo.")
# Out:
# Epoch 1/20 - Loss: 1.0319 - Accuracy: 0.076
# Epoch 2/20 - Loss: 1.0202 - Accuracy: 0.112
# Epoch 3/20 - Loss: 1.0779 - Accuracy: 0.093
# Epoch 4/20 - Loss: 1.0227 - Accuracy: 0.090
# Epoch 5/20 - Loss: 1.0318 - Accuracy: 0.147
# Epoch 6/20 - Loss: 1.0486 - Accuracy: 0.173
# Epoch 7/20 - Loss: 1.0327 - Accuracy: 0.210
# Epoch 8/20 - Loss: 0.9990 - Accuracy: 0.212
# Epoch 9/20 - Loss: 1.0442 - Accuracy: 0.243
# Epoch 10/20 - Loss: 1.0394 - Accuracy: 0.209
# Epoch 11/20 - Loss: 0.9817 - Accuracy: 0.231
# Epoch 12/20 - Loss: 0.9751 - Accuracy: 0.269
# Epoch 13/20 - Loss: 1.0612 - Accuracy: 0.261
# Epoch 14/20 - Loss: 1.0540 - Accuracy: 0.270
# Epoch 15/20 - Loss: 0.9995 - Accuracy: 0.348
# Epoch 16/20 - Loss: 1.0469 - Accuracy: 0.333
# Epoch 17/20 - Loss: 1.0298 - Accuracy: 0.329
# Epoch 18/20 - Loss: 1.0127 - Accuracy: 0.400
# Epoch 19/20 - Loss: 1.0401 - Accuracy: 0.363
# Epoch 20/20 - Loss: 1.0413 - Accuracy: 0.400
# 2025/08/31 15:13:56 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/08/31 15:14:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Simulación finalizada. Revisa MLflow UI para ver métricas y modelo.
